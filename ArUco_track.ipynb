# %%
import cv2
import numpy as np
import argparse
import sys

# %%
#https://learnopencv.com/augmented-reality-using-aruco-markers-in-opencv-c-python/

dictionary=cv2.aruco.Dictionary_get(cv2.aruco.DICT_4X4_250)

markerImage=np.zeros((200,200),dtype=np.uint8)

markerImage=cv2.aruco.drawMarker(dictionary,73,200, markerImage, 1);

cv2.imwrite("./Tags/aurco_44_250_73.png", markerImage);

# %%
# construct the argument parser and parse the arguments
ap = argparse.ArgumentParser()
ap.add_argument("-i", "--image", required=True,
	help="path to input image containing ArUCo tag")
ap.add_argument("-t", "--type", type=str,
	default="DICT_ARUCO_ORIGINAL",
	help="type of ArUCo tag to detect")
args = vars(ap.parse_args())

# %%
# define names of each possible ArUco tag OpenCV supports
ARUCO_DICT = {
	"DICT_4X4_50": cv2.aruco.DICT_4X4_50,
	"DICT_4X4_100": cv2.aruco.DICT_4X4_100,
	"DICT_4X4_250": cv2.aruco.DICT_4X4_250,
	"DICT_4X4_1000": cv2.aruco.DICT_4X4_1000,
	"DICT_5X5_50": cv2.aruco.DICT_5X5_50,
	"DICT_5X5_100": cv2.aruco.DICT_5X5_100,
	"DICT_5X5_250": cv2.aruco.DICT_5X5_250,
	"DICT_5X5_1000": cv2.aruco.DICT_5X5_1000,
	"DICT_6X6_50": cv2.aruco.DICT_6X6_50,
	"DICT_6X6_100": cv2.aruco.DICT_6X6_100,
	"DICT_6X6_250": cv2.aruco.DICT_6X6_250,
	"DICT_6X6_1000": cv2.aruco.DICT_6X6_1000,
	"DICT_7X7_50": cv2.aruco.DICT_7X7_50,
	"DICT_7X7_100": cv2.aruco.DICT_7X7_100,
	"DICT_7X7_250": cv2.aruco.DICT_7X7_250,
	"DICT_7X7_1000": cv2.aruco.DICT_7X7_1000,
	"DICT_ARUCO_ORIGINAL": cv2.aruco.DICT_ARUCO_ORIGINAL,
	"DICT_APRILTAG_16h5": cv2.aruco.DICT_APRILTAG_16h5,
	"DICT_APRILTAG_25h9": cv2.aruco.DICT_APRILTAG_25h9,
	"DICT_APRILTAG_36h10": cv2.aruco.DICT_APRILTAG_36h10,
	"DICT_APRILTAG_36h11": cv2.aruco.DICT_APRILTAG_36h11
}

# %%
frame=cv2.imread('t10.png')
dictionary=cv2.aruco.Dictionary_get(cv2.aruco.DICT_4X4_100)
#arucoDict = cv2.aruco.Dictionary_get(cv2.aruco.DICT_APRILTAG_36h11))
parameters=cv2.aruco.DetectorParameters_create()
# Detect the markers in the image
markerCorners, markerIds, rejectedCandidates = cv2.aruco.detectMarkers(frame, dictionary, parameters=parameters)

# %%
# verify *at least* one ArUco marker was detected
if len(markerCorners) > 0:
    # flatten the ArUco IDs list
    ids = markerIds.flatten()
    # loop over the detected ArUCo corners
    for (markerCorner, markerID) in zip(markerCorners, ids):
        # extract the marker corners (which are always returned in
        # top-left, top-right, bottom-right, and bottom-left order)
        #markerCorners=np.reshape(markerCorners,(16,4))
        #corners = np.reshape(markerCorners, (16,8))
        corners = markerCorner.reshape((4, 2))
        (topLeft, topRight, bottomRight, bottomLeft) = corners
        # convert each of the (x, y)-coordinate pairs to integers
        topRight = (int(topRight[0]), int(topRight[1]))
        bottomRight = (int(bottomRight[0]), int(bottomRight[1]))
        bottomLeft = (int(bottomLeft[0]), int(bottomLeft[1]))
        topLeft = (int(topLeft[0]), int(topLeft[1]))

# %%
# Bounding boxes
# draw the bounding box of the ArUCo detection
cv2.line(frame, topLeft, topRight, (0, 0, 255), 2)
cv2.line(frame, topRight, bottomRight, (0, 0, 255), 2)
cv2.line(frame, bottomRight, bottomLeft, (0, 0, 255), 2)
cv2.line(frame, bottomLeft, topLeft, (0, 0, 255), 2)

# %%
#ArUco Id in centre
# draw the ArUco marker ID on the image
cv2.putText(frame, str(markerIds),
			(topLeft[0],topLeft[1] - 15), cv2.FONT_HERSHEY_SIMPLEX,
			0.5, (255, 0, 0), 2)
print("[INFO] ArUco marker ID: {}".format(markerID))

# %%
# compute and draw the center (x, y)-coordinates of the
			# ArUco marker
cX = int((topLeft[0] + bottomRight[0]) / 2.0)
cY = int((topLeft[1] + bottomRight[1]) / 2.0)
cv2.circle(frame, (cX, cY), 4, (0, 0, 255), -1)

# %%
cv2.imshow('img1', frame)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imwrite('./Results/exp7.png', frame)

# %%
frame=cv2.imread('t10.png')
dictionary=cv2.aruco.Dictionary_get(cv2.aruco.DICT_4X4_100)
#arucoDict = cv2.aruco.Dictionary_get(cv2.aruco.DICT_APRILTAG_36h11))
parameters=cv2.aruco.DetectorParameters_create()
# Detect the markers in the image
markerCorners, markerIds, rejectedCandidates = cv2.aruco.detectMarkers(frame, dictionary, parameters=parameters)

# verify *at least* one ArUco marker was detected
if len(markerCorners) > 0:
    # flatten the ArUco IDs list
    markerIds = markerIds.flatten()
    # loop over the detected ArUCo corners
    for (markerCorner, markerID) in zip(markerCorners, markerIds):
        # extract the marker corners (which are always returned in
        # top-left, top-right, bottom-right, and bottom-left order)
        #markerCorners=np.reshape(markerCorners,(16,4))
        #corners = np.reshape(markerCorners, (16,8))
        corners = markerCorner.reshape((4, 2))
        (topLeft, topRight, bottomRight, bottomLeft) = corners
        # convert each of the (x, y)-coordinate pairs to integers
        topRight = (int(topRight[0]), int(topRight[1]))
        bottomRight = (int(bottomRight[0]), int(bottomRight[1]))
        bottomLeft = (int(bottomLeft[0]), int(bottomLeft[1]))
        topLeft = (int(topLeft[0]), int(topLeft[1]))
        
        # Bounding boxes
        # draw the bounding box of the ArUCo detection
        cv2.line(frame, topLeft, topRight, (0, 0, 255), 2)
        cv2.line(frame, topRight, bottomRight, (0, 0, 255), 2)
        cv2.line(frame, bottomRight, bottomLeft, (0, 0, 255), 2)
        cv2.line(frame, bottomLeft, topLeft, (0, 0, 255), 2)
        
        
        
        # compute and draw the center (x, y)-coordinates of the
        # ArUco marker
        cX = int((topLeft[0] + bottomRight[0]) / 2.0)
        cY = int((topLeft[1] + bottomRight[1]) / 2.0)
        cv2.circle(frame, (cX, cY), 4, (0, 0, 255), -1)
        
        #ArUco Id in centre
        # draw the ArUco marker ID on the image
        cv2.putText(frame, str(markerID),
        (topLeft[0],topLeft[1] - 15), 
                    cv2.FONT_HERSHEY_SIMPLEX,
            0.5, (255, 0, 0), 2)
        print("[INFO] ArUco marker ID: {}".format(markerID))
# Out:
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73

# %%
cv2.imshow('img1', frame)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imwrite('./Results/exp10.png', frame)
# Out:
# True

# %% [markdown]
# # Video Input

# %%
import cv2
import numpy as np

vid = cv2.VideoCapture(0)
  
while(True):
      
    ret, frame = vid.read()
    
    dictionary=cv2.aruco.Dictionary_get(cv2.aruco.DICT_4X4_100)
    parameters=cv2.aruco.DetectorParameters_create()
    # Detect the markers in the image
    markerCorners, markerIds, rejectedCandidates = cv2.aruco.detectMarkers(frame, dictionary, parameters=parameters)
    
    # verify *at least* one ArUco marker was detected
    if len(markerCorners) > 0:
        # flatten the ArUco IDs list
        markerIds = markerIds.flatten()
        # loop over the detected ArUCo corners
        for (markerCorner, markerID) in zip(markerCorners, markerIds):
            # extract the marker corners (which are always returned in
            # top-left, top-right, bottom-right, and bottom-left order)
            corners = markerCorner.reshape((4, 2))
            (topLeft, topRight, bottomRight, bottomLeft) = corners
            # convert each of the (x, y)-coordinate pairs to integers
            topRight = (int(topRight[0]), int(topRight[1]))
            bottomRight = (int(bottomRight[0]), int(bottomRight[1]))
            bottomLeft = (int(bottomLeft[0]), int(bottomLeft[1]))
            topLeft = (int(topLeft[0]), int(topLeft[1]))
            
            # Bounding boxes
            # draw the bounding box of the ArUCo detection
            cv2.line(frame, topLeft, topRight, (0, 0, 255), 2)
            cv2.line(frame, topRight, bottomRight, (0, 0, 255), 2)
            cv2.line(frame, bottomRight, bottomLeft, (0, 0, 255), 2)
            cv2.line(frame, bottomLeft, topLeft, (0, 0, 255), 2)     

            #ArUco Id in centre
            # draw the ArUco marker ID on the image
            cv2.putText(frame, str(markerID),
            (topLeft[0],topLeft[1] - 15), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 0), 2)
            print("[INFO] ArUco marker ID: {}".format(markerID))
            
            
            # compute and draw the center (x, y)-coordinates of the
            # ArUco marker
            cX = int((topLeft[0] + bottomRight[0]) / 2.0)
            cY = int((topLeft[1] + bottomRight[1]) / 2.0)
            cv2.circle(frame, (cX, cY), 4, (0, 0, 255), -1)
            
    cv2.imshow('frame', frame)
            
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
  
vid.release()
# Destroy all the windows
cv2.destroyAllWindows()
# Out:
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 17
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 17
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 17
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 17
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 17
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 37
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# ...
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 37
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 73
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 71
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 72
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 70
# [INFO] ArUco marker ID: 70

# %%
cv2.imwrite('./Results/exp10.mp4', frame)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 cv2.imwrite('./Results/exp10.mp4', frame)
#
# error: OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:730: error: (-2:Unspecified error) could not find a writer for the specified extension in function 'cv::imwrite_'

# %%
import cv2
import numpy as np

vid = cv2.VideoCapture(0)
  
while(True):
      
    ret, frame = vid.read()
    
    dictionary=cv2.aruco.Dictionary_get(cv2.aruco.DICT_4X4_100)
    parameters=cv2.aruco.DetectorParameters_create()
    # Detect the markers in the image
    markerCorners, markerIds, rejectedCandidates = cv2.aruco.detectMarkers(frame, dictionary, parameters=parameters)
    
    # verify *at least* one ArUco marker was detected
    if len(markerCorners) > 0:
        # flatten the ArUco IDs list
        ids = markerIds.flatten()
        # loop over the detected ArUCo corners
        for (markerCorner, markerID) in zip(markerCorners, ids):
            # extract the marker corners (which are always returned in
            # top-left, top-right, bottom-right, and bottom-left order)
            markerCorners=np.array(markerCorners)
            corners = np.reshape(markerCorners, (4,2))
            #corners = markerCorners.reshape((4, 2))
            
            (topLeft, topRight, bottomRight, bottomLeft) = corners
            # convert each of the (x, y)-coordinate pairs to integers
            topRight = (int(topRight[0]), int(topRight[1]))
            bottomRight = (int(bottomRight[0]), int(bottomRight[1]))
            bottomLeft = (int(bottomLeft[0]), int(bottomLeft[1]))
            topLeft = (int(topLeft[0]), int(topLeft[1]))
            
            # Bounding boxes
            # draw the bounding box of the ArUCo detection
            cv2.line(frame, topLeft, topRight, (0, 0, 255), 2)
            cv2.line(frame, topRight, bottomRight, (0, 0, 255), 2)
            cv2.line(frame, bottomRight, bottomLeft, (0, 0, 255), 2)
            cv2.line(frame, bottomLeft, topLeft, (0, 0, 255), 2)     

            #ArUco Id in centre
            # draw the ArUco marker ID on the image
            cv2.putText(frame, str(markerIds),
            (topLeft[0],topLeft[1] - 15), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 0), 2)
            print("[INFO] ArUco marker ID: {}".format(markerID))
            
            
            # compute and draw the center (x, y)-coordinates of the
            # ArUco marker
            cX = int((topLeft[0] + bottomRight[0]) / 2.0)
            cY = int((topLeft[1] + bottomRight[1]) / 2.0)
            cv2.circle(frame, (cX, cY), 4, (0, 0, 255), -1)
            
    cv2.imshow('frame', frame)
            
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
  
vid.release()
# Destroy all the windows
cv2.destroyAllWindows()
